# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("agr_en_dev.csv")

# %%
df.head()
# Out:
#     facebook_corpus_msr_451811  \
# 0   facebook_corpus_msr_334368
# 1   facebook_corpus_msr_331195
# 2   facebook_corpus_msr_403402
# 3   facebook_corpus_msr_379239
# 4  facebook_corpus_msr_2111264
#
#   The quality of re made now makes me think it is something to be bought from fish market  \
# 0  @siva \nHow is ur mother???\nHow is ur wife???...
# 1  Also see ....hw ur RSS activist caught in Burk...
# 2  On the death of 2 jawans in LOC CROSS FIRING\n...
# 3  Modi ho ya Manmohan singh saala yeh log kuch n...
# 4  No discrimination in policies and NON protecti...
#
#    CAG
# 0  NAG
# 1  NAG
# 2  NAG
# 3  OAG
# 4  CAG

# %%
df.shape
# Out:
# (3000, 3)

# %%
df1=pd.read_csv("agr_en_train.csv",header=None)

# %%
df1.head()
# Out:
#                              0  \
# 0  facebook_corpus_msr_1723796
# 1   facebook_corpus_msr_466073
# 2  facebook_corpus_msr_1493901
# 3   facebook_corpus_msr_405512
# 4  facebook_corpus_msr_1521685
#
#                                                    1    2
# 0  Well said sonu..you have courage to stand agai...  OAG
# 1  Most of Private Banks ATM's Like HDFC, ICICI e...  NAG
# 2     Now question is, Pakistan will adhere to this?  OAG
# 3  Pakistan is comprised of fake muslims who does...  OAG
# 4  ??we r against cow slaughter,so of course it w...  NAG

# %%
df1.shape
# Out:
# (12000, 3)

# %%
df1 = df1.rename(columns={0: 'id', 1: 'text', 2: 'label'})

# %%
df1.head()
# Out:
#                             id  \
# 0  facebook_corpus_msr_1723796
# 1   facebook_corpus_msr_466073
# 2  facebook_corpus_msr_1493901
# 3   facebook_corpus_msr_405512
# 4  facebook_corpus_msr_1521685
#
#                                                 text label
# 0  Well said sonu..you have courage to stand agai...   OAG
# 1  Most of Private Banks ATM's Like HDFC, ICICI e...   NAG
# 2     Now question is, Pakistan will adhere to this?   OAG
# 3  Pakistan is comprised of fake muslims who does...   OAG
# 4  ??we r against cow slaughter,so of course it w...   NAG

# %%
df1.drop(columns=['id'],inplace=True)

# %%
df1.head()
# Out:
#                                                 text label
# 0  Well said sonu..you have courage to stand agai...   OAG
# 1  Most of Private Banks ATM's Like HDFC, ICICI e...   NAG
# 2     Now question is, Pakistan will adhere to this?   OAG
# 3  Pakistan is comprised of fake muslims who does...   OAG
# 4  ??we r against cow slaughter,so of course it w...   NAG

# %%
df1['label'].value_counts()
# Out:
# label
# NAG    5052
# CAG    4240
# OAG    2708
# Name: count, dtype: int64

# %%
df1['label']=df1['label'].replace(['CAG','OAG'],'hate')
df1['label']=df1['label'].replace(['NAG'],'non-hate')

# %%
df1.head(2)
# Out:
#                                                 text     label
# 0  Well said sonu..you have courage to stand agai...      hate
# 1  Most of Private Banks ATM's Like HDFC, ICICI e...  non-hate

# %%
df1['label'].value_counts()
# Out:
# label
# hate        6948
# non-hate    5052
# Name: count, dtype: int64

# %%
df1['label_num'] = df1['label'].map({'hate': 0, 'non-hate': 1})

# %%
import re

def detect_hinglish(text):
    if not isinstance(text, str):  # handle NaN or non-string
        return "unknown"
  
    has_hindi = bool(re.search(r'[\u0900-\u097F]', text))
    has_english = bool(re.search(r'[a-zA-Z]', text))

    words = set(text.lower().split())


  
    if has_hindi:
        return 'Hindi'
    elif has_english:
        return 'English'
    else:
        return 'Other/None'

# %%
df1['language']=df1['text'].apply(detect_hinglish)

# %%
df1.head()
# Out:
#                                                 text     label  label_num  \
# 0  Well said sonu..you have courage to stand agai...      hate          0
# 1  Most of Private Banks ATM's Like HDFC, ICICI e...  non-hate          1
# 2     Now question is, Pakistan will adhere to this?      hate          0
# 3  Pakistan is comprised of fake muslims who does...      hate          0
# 4  ??we r against cow slaughter,so of course it w...  non-hate          1
#
#   language
# 0  English
# 1  English
# 2  English
# 3  English
# 4  English

# %%
df1['language'].value_counts()
# Out:
# language
# English       11972
# Hindi            27
# Other/None        1
# Name: count, dtype: int64

# %%
data1=pd.DataFrame()

# %%
data1=df1[df1['language']=='English']

# %%
data1.drop(columns=['label','language'],inplace=True)
# Out:
# C:\Users\Mcc\AppData\Local\Temp\ipykernel_9704\4098247466.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(columns=['label','language'],inplace=True)

# %%
data1.head()
# Out:
#                                                 text  label_num
# 0  Well said sonu..you have courage to stand agai...          0
# 1  Most of Private Banks ATM's Like HDFC, ICICI e...          1
# 2     Now question is, Pakistan will adhere to this?          0
# 3  Pakistan is comprised of fake muslims who does...          0
# 4  ??we r against cow slaughter,so of course it w...          1

# %%
df2=pd.read_csv("agr_hi_train.csv",header=None)

# %%
df2.head()
# Out:
#                             0  \
# 0  facebook_corpus_msr_401470
# 1  facebook_corpus_msr_386695
# 2  facebook_corpus_msr_373389
# 3  facebook_corpus_msr_917635
# 4  facebook_corpus_msr_382517
#
#                                                    1    2
# 0  Mahmood Ghaznavi Aor ABdali ko bhol gaya ha tu...  OAG
# 1  Bhai 60sal pehle desh me kya tha pehle pta kro...  CAG
# 2  chutiya friday ko isliye releae krte kyoki wee...  CAG
# 3                                         जय मोदीराज  CAG
# 4     UPA walo ne bahot kuch kr diya tha desh k liye  CAG

# %%
df2 = df2.rename(columns={0: 'id', 1: 'text', 2: 'label'})

# %%
df2.head()
# Out:
#                            id  \
# 0  facebook_corpus_msr_401470
# 1  facebook_corpus_msr_386695
# 2  facebook_corpus_msr_373389
# 3  facebook_corpus_msr_917635
# 4  facebook_corpus_msr_382517
#
#                                                 text label
# 0  Mahmood Ghaznavi Aor ABdali ko bhol gaya ha tu...   OAG
# 1  Bhai 60sal pehle desh me kya tha pehle pta kro...   CAG
# 2  chutiya friday ko isliye releae krte kyoki wee...   CAG
# 3                                         जय मोदीराज   CAG
# 4     UPA walo ne bahot kuch kr diya tha desh k liye   CAG

# %%
df2['lang']=df2['text'].apply(detect_hinglish)

# %%
df2['text'] = df2['text'].fillna('').astype(str)

# %%
df2.head()
# Out:
#                            id  \
# 0  facebook_corpus_msr_401470
# 1  facebook_corpus_msr_386695
# 2  facebook_corpus_msr_373389
# 3  facebook_corpus_msr_917635
# 4  facebook_corpus_msr_382517
#
#                                                 text label     lang
# 0  Mahmood Ghaznavi Aor ABdali ko bhol gaya ha tu...   OAG  English
# 1  Bhai 60sal pehle desh me kya tha pehle pta kro...   CAG  English
# 2  chutiya friday ko isliye releae krte kyoki wee...   CAG  English
# 3                                         जय मोदीराज   CAG    Hindi
# 4     UPA walo ne bahot kuch kr diya tha desh k liye   CAG  English

# %%
df2['lang'].value_counts()
# Out:
# lang
# English    8878
# Hindi      3121
# unknown       1
# Name: count, dtype: int64

# %%
data2=pd.DataFrame()

# %%
data2=df2[df2['lang']=='English']

# %%
data2.head()
# Out:
#                            id  \
# 0  facebook_corpus_msr_401470
# 1  facebook_corpus_msr_386695
# 2  facebook_corpus_msr_373389
# 4  facebook_corpus_msr_382517
# 5  facebook_corpus_msr_403274
#
#                                                 text label     lang
# 0  Mahmood Ghaznavi Aor ABdali ko bhol gaya ha tu...   OAG  English
# 1  Bhai 60sal pehle desh me kya tha pehle pta kro...   CAG  English
# 2  chutiya friday ko isliye releae krte kyoki wee...   CAG  English
# 4     UPA walo ne bahot kuch kr diya tha desh k liye   CAG  English
# 5  Pan ko Aadhar se link ki zarurat kuy hai? Supr...   CAG  English

# %%
data2.drop(columns=['id'],inplace=True)
# Out:
# C:\Users\Mcc\AppData\Local\Temp\ipykernel_9704\2045726565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.drop(columns=['id'],inplace=True)

# %%
data2.shape
# Out:
# (8878, 3)

# %%
data2['Label']=data2['label'].map({'CAG': 'hate', 'OAG': 'hate', 'NAG': 'non hate'})
# Out:
# C:\Users\Mcc\AppData\Local\Temp\ipykernel_9704\2971654867.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['Label']=data2['label'].map({'CAG': 'hate', 'OAG': 'hate', 'NAG': 'non hate'})

# %%
data2.head()
# Out:
#                                                 text label     lang Label
# 0  Mahmood Ghaznavi Aor ABdali ko bhol gaya ha tu...   OAG  English  hate
# 1  Bhai 60sal pehle desh me kya tha pehle pta kro...   CAG  English  hate
# 2  chutiya friday ko isliye releae krte kyoki wee...   CAG  English  hate
# 4     UPA walo ne bahot kuch kr diya tha desh k liye   CAG  English  hate
# 5  Pan ko Aadhar se link ki zarurat kuy hai? Supr...   CAG  English  hate

# %%
data2['label_num']=data2['Label'].map({'hate':0,'non hate':1})
# Out:
# C:\Users\Mcc\AppData\Local\Temp\ipykernel_9704\3621052426.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['label_num']=data2['Label'].map({'hate':0,'non hate':1})

# %%
data2.head()
# Out:
#                                                 text label     lang Label  \
# 0  Mahmood Ghaznavi Aor ABdali ko bhol gaya ha tu...   OAG  English  hate
# 1  Bhai 60sal pehle desh me kya tha pehle pta kro...   CAG  English  hate
# 2  chutiya friday ko isliye releae krte kyoki wee...   CAG  English  hate
# 4     UPA walo ne bahot kuch kr diya tha desh k liye   CAG  English  hate
# 5  Pan ko Aadhar se link ki zarurat kuy hai? Supr...   CAG  English  hate
#
#    label_num
# 0          0
# 1          0
# 2          0
# 4          0
# 5          0

# %%
data2.drop(columns=['label','Label','lang'],inplace=True)
# Out:
# C:\Users\Mcc\AppData\Local\Temp\ipykernel_9704\4188967387.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2.drop(columns=['label','Label','lang'],inplace=True)

# %%
data2.head()
# Out:
#                                                 text  label_num
# 0  Mahmood Ghaznavi Aor ABdali ko bhol gaya ha tu...          0
# 1  Bhai 60sal pehle desh me kya tha pehle pta kro...          0
# 2  chutiya friday ko isliye releae krte kyoki wee...          0
# 4     UPA walo ne bahot kuch kr diya tha desh k liye          0
# 5  Pan ko Aadhar se link ki zarurat kuy hai? Supr...          0

# %%
data2['label_num'].value_counts()
# Out:
# label_num
# 0    7469
# 1    1409
# Name: count, dtype: int64

# %%
final_data=pd.concat([data1,data2],axis=0)

# %%
final_data.head()
# Out:
#                                                 text  label_num
# 0  Well said sonu..you have courage to stand agai...          0
# 1  Most of Private Banks ATM's Like HDFC, ICICI e...          1
# 2     Now question is, Pakistan will adhere to this?          0
# 3  Pakistan is comprised of fake muslims who does...          0
# 4  ??we r against cow slaughter,so of course it w...          1

# %%
final_data.shape
# Out:
# (20850, 2)

# %%
final_data['label_num'].value_counts()
# Out:
# label_num
# 0    14398
# 1     6452
# Name: count, dtype: int64

# %%
data_0=final_data[final_data['label_num']==0]
data_1=final_data[final_data['label_num']==1]

# %%
len(data_0)
# Out:
# 14398

# %%
len(data_1)
# Out:
# 6452

# %%
from sklearn.model_selection import train_test_split

# %%
import string
import re

# %%
english_punctuations = string.punctuation

# %%
import nltk

# %%
from nltk.corpus import stopwords
stopwords_en = set(stopwords.words('english'))

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet

# %%
lemmatizer = WordNetLemmatizer()

# %%
import re
import emoji
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from fuzzywuzzy import process
import pandas as pd
from tqdm import tqdm

# NLTK downloads
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("stopwords")

lemmatizer = WordNetLemmatizer()
english_stopwords = set(stopwords.words("english"))

# Base abusive words dictionary
ABUSE_DICT = {
    "bc": "behenchod",
    "b.c": "behenchod",
    "b!c": "behenchod",
    "mc": "madarchod",
    "m.c": "madarchod",
    "c**t": "chutiya",
    "ch*tiya": "chutiya",
    "chu*ya": "chutiya",
    "bkl": "behen ke laude",
    "bhkl": "behen ke laude",
}

# Automatically generate common obfuscation variations
def generate_variations(word):
    variants = set()
    variants.add(word)
    variants.add(word.replace("c", "*"))
    variants.add(word.replace("c", "!"))
    variants.add(word.replace("o", "0"))
    variants.add(word.replace("e", "3"))
    return variants

for key in list(ABUSE_DICT.keys()):
    for v in generate_variations(key):
        ABUSE_DICT[v] = ABUSE_DICT[key]

# Hinglish pattern normalization
HINGLISH_PATTERNS = {
    r"g(a|aa|aaa|)ndu+": "gandu",
    r"m(a|aa|aaa|)d(a|aa)rch(o|oo)d": "madarchod",
    r"b(e|ee|i)h(e|i)nchod": "behenchod",
    r"ch(u|oo)t(iy|iya|iya*)": "chutiya",
}

def normalize_hinglish(word):
    for p, norm in HINGLISH_PATTERNS.items():
        if re.fullmatch(p, word):
            return norm
    return word

# Emoji conversion (dynamic)
def convert_emoji_auto(text):
    text = emoji.demojize(text)
    text = re.sub(r":([a-z_]+):", r" \1 ", text)  # replace all emojis with their name
    return text

# Deobfuscate symbols and numbers
def deobfuscate(text):
    # Remove everything except letters and spaces
    text = re.sub(r"[^a-zA-Z\s]", " ", text)
    
    # Collapse multiple spaces into one
    text = re.sub(r"\s+", " ", text).strip()
    return text

# Reduce elongated words
def reduce_lengthening(text):
    return re.sub(r"(.)\1{2,}", r"\1", text)  # aaa -> a

# Expand known abusive words / slangs
def expand_slang(text):
    words = text.split()
    new = []
    for w in words:
        lw = w.lower()
        if lw in ABUSE_DICT:
            new.append(ABUSE_DICT[lw])
        else:
            new.append(w)
    return " ".join(new)

# Lemmatize and remove stopwords
def normalize_english(word):
    w = lemmatizer.lemmatize(word)
    if w not in english_stopwords:
        return w
    return ""

# Fuzzy matching for unknown abusive words
def fuzzy_abuse_normalize(word, abuse_list, threshold=85):
    match, score = process.extractOne(word, abuse_list)
    if score >= threshold:
        return match
    return word

# Full preprocessing pipeline
def preprocess_text(text, use_fuzzy=True):
    text = text.lower()
    text = convert_emoji_auto(text)
    text = deobfuscate(text)
    text = reduce_lengthening(text)
    text = expand_slang(text)
    
    words = nltk.word_tokenize(text)
    normalized_words = []
    abuse_list = list(ABUSE_DICT.values())
    
    for w in words:
        w = normalize_hinglish(w)
        w = normalize_english(w)
        if not w:
            continue
        if use_fuzzy:
            w = fuzzy_abuse_normalize(w, abuse_list)
        normalized_words.append(w)
    
    return " ".join(normalized_words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Mcc\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Mcc\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Mcc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
tqdm.pandas()

# %%
final_data["cleaned_text"] = final_data["text"].progress_apply(preprocess_text)
# Out:
#  26%|████████████████████▏                                                        | 5451/20850 [06:27<18:13, 14.08it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\fuzzywuzzy\process.py:108, in extractWithoutOrder(query, choices, processor, scorer, score_cutoff)
#     106 try:
#     107     # See if choices is a dictionary-like object.
# --> 108     for key, choice in choices.items():
#     109         processed = pre_processor(processor(choice))
#
# AttributeError: 'list' object has no attribute 'items'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 final_data["cleaned_text"] = final_data["text"].progress_apply(preprocess_text)
#
# ...

# %%
final_data.head()

# %%
final_data.drop(['text'], axis=1, inplace=True)

# %%
final_data.head()

# %%
final_data = final_data.replace(r'^\s*$', np.nan, regex=True)

# %%
empty_rows = final_data[final_data.isna().all(axis=1)]
print(empty_rows)

# %%
final_data = final_data.dropna(how='all', axis=0)

# %%
final_data.head()

# %%
final_data.shape

# %%
x=final_data['cleaned_text']
y=final_data['label_num']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    x, y, test_size=0.2, random_state=42, stratify=y
)

# %%
# !pip install imbalanced-learn

# %%
from imblearn.over_sampling import SMOTE

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=10000)

# %%
x.shape

# %%
y.shape

# %%
import pandas as pd

# Assuming x is a Pandas Series
empty_or_nan_idx = x[x.isna() | (x.str.strip() == '')].index

print("Indices of empty or NaN rows in x:")
print(empty_or_nan_idx.tolist())

# %%
x.shape

# %%
# Drop these rows from both x and y
x_clean = x.drop(index=empty_or_nan_idx)
y_clean = y.drop(index=empty_or_nan_idx)

# Optional: reset index so both x_clean and y_clean align
x_clean = x_clean.reset_index(drop=True)
y_clean = y_clean.reset_index(drop=True)

# %%
x_clean.shape

# %%
y_clean.shape

# %%
x_bow=cv.fit_transform(x_clean).toarray()

# %%
x_bow.shape

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x_bow,y_clean,test_size=0.2,random_state=42)

# %%
smote = SMOTE(random_state=42)
x_train_res, y_train_res = smote.fit_resample(x_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression(max_iter=2000)

# %%
clf.fit(x_train_res, y_train_res)

# %%
y_pred = clf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)

# %%
y_test.shape

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))

# %%
clf = LogisticRegression(class_weight='balanced')

# %%
clf.fit(x_train_res, y_train_res)

# %%
y_pred = clf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)

# %%
y_test.shape

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt=DecisionTreeClassifier()

# %%
dt.fit(x_train_res,y_train_res)

# %%
y_pred=dt.predict(x_test)

# %%
accuracy_score(y_test,y_pred)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(
    n_estimators=100,  
    max_depth=None,   
    random_state=42,
    n_jobs=-1          
)

# %%
rf.fit(x_train_res,y_train_res)

# %%
y_pred=rf.predict(x_test)

# %%
accuracy_score(y_test,y_pred)

# %%
from sklearn.svm import LinearSVC

# %%
svm= LinearSVC()

# %%
svm.fit(x_train_res,y_train_res)

# %%
preds = svm.predict(x_test)

# %%
accuracy_score(y_test,preds)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(kernel='rbf', C=1.0, gamma='scale')  # gamma='scale' is default
svc.fit(x_train_res, y_train_res)

# %%
y_pred = svc.predict(x_test)

# Accuracy
acc = accuracy_score(y_test, y_pred)
print("Accuracy:", acc)

# %%
import lightgbm as lgb

# %%
lgbm = lgb.LGBMClassifier()

# %%
lgbm.fit(x_train_res, y_train_res)

# %%
y_pred=lgbm.predict(x_test)

# %%
accuracy_score(y_test,y_pred)

# %%
from catboost import CatBoostClassifier

# %%
model = CatBoostClassifier(verbose=0)
model.fit(x_train_res, y_train_res)

# %%
y_pred=model.predict(x_test)

# %%
accuracy_score(y_test,y_pred)

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbc = GradientBoostingClassifier(
    n_estimators=100,   # Number of trees
    learning_rate=0.1,  # Step size
    max_depth=3,        # Depth of each tree
    random_state=42
)

# %%
gbc.fit(x_train_res, y_train_res )

# %%
y_pred=gbc.predict(x_test)

# %%
accuracy_score(y_test,y_pred)

# %% [markdown]
# tf-idf

# %%
from sklearn.feature_extraction.text import TfidfVectorizer


tf = TfidfVectorizer(max_features=5000, stop_words='english')

# %%
x_tf=tf.fit_transform(x_clean).toarray()

# %%
from sklearn.model_selection import train_test_split
x_train_tf,x_test_tf,y_train_tf,y_test_tf=train_test_split(x_tf,y_clean,test_size=0.2,random_state=42)

# %%
smote = SMOTE(random_state=42)
x_train_res_tf, y_train_res_tf = smote.fit_resample(x_train_tf, y_train_tf)

# %%
clf = LogisticRegression(max_iter=2000)

# %%
clf.fit(x_train_res_tf, y_train_res_tf )
# Out:
# LogisticRegression(max_iter=2000)

# %%
y_pred=clf.predict(x_test_tf)

# %%
accuracy_score(y_pred,y_test_tf)
# Out:
# 0.748918789043729

# %%
clf1 = LogisticRegression(class_weight='balanced')

# %%
clf1.fit(x_train_res_tf, y_train_res_tf )
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred=clf1.predict(x_test_tf)

# %%
accuracy_score(y_pred,y_test_tf)
# Out:
# 0.748918789043729

# %%
from gensim.models import Word2Vec

# %%
def tokenization(text):
    text=text.lower()
    return text.split()

# %%
x_token=x_clean.apply(tokenization)

# %%
x_token.head
# Out:
# <bound method NDFrame.head of 0        [well, said, sonu, courage, stand, dadagiri, m...
# 1        [private, bank, atm, like, hdfc, icici, etc, c...
# 2                             [question, pakistan, adhere]
# 3        [pakistan, comprised, fake, muslim, doe, know,...
# 4        [r, cow, slaughter, course, stop, leather, man...
#                                ...
# 20804    [pakistani, border, action, force, bat, loc, s...
# 20805    [kisi, dushre, desho, ki, soldier, k, sar, kat...
# 20806                          [kyoki, wo, hindu, chutiya]
# 20807    [mileage, ki, tension, na, lo, india, k, upar,...
# 20808    [gulamo, ki, baat, ka, bura, nahi, mantey, bha...
# Name: cleaned_text, Length: 20809, dtype: object>

# %%
model = Word2Vec(
    sentences=x_token,
    vector_size=200,   # embedding dimension
    window=5,          # context window
    min_count=2,       # ignore rare words
    sg=0,              # 1 = Skip-Gram, 0 = CBOW
    workers=-1,         # parallel threads
    epochs=10
)

# %%
model.save("word2vec_model.model")

# %%
words = list(model.wv.index_to_key)
print(words[:2])
# Out:
# ['hai', 'chutiya']

# %%
vector = model.wv['hai']  # 'example' must be in your vocabulary
print(vector.shape)
# Out:
# (200,)

# %%
import numpy as np

def document_vector(tokens):
    
    tokens = [word for word in tokens if word in model.wv.index_to_key]
    if len(tokens) == 0:
        return np.zeros(model.vector_size)
    return np.mean(model.wv[tokens], axis=0)


X = np.array([document_vector(tokens) for tokens in x_clean])

# %%
X_train_w, X_test_w, y_train_w, y_test_w = train_test_split(X, y_clean, test_size=0.2, random_state=42)

# %%
smote = SMOTE(random_state=42)
X_train_res_w, y_train_res_w = smote.fit_resample(X_train_w, y_train_w)

# %%
clf.fit(X_train_res_w,y_train_res_w)
# Out:
# LogisticRegression(class_weight='balanced')

# %%
y_pred=clf.predict(X_test_w)

# %%
accuracy_score(y_test_w,y_pred)
# Out:
# 0.6874098990869774

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('xlm-r-distilroberta-base-paraphrase-v1')
embeddings = model.encode(x_clean.astype(str).tolist(), show_progress_bar=True)
# Out:
# WARNING:tensorflow:From C:\Users\Mcc\AppData\Local\Programs\Python\Python313\Lib\site-packages\tf_keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# Batches:   0%|          | 0/651 [00:00<?, ?it/s]

# %%
X = embeddings

# %%
X_train_b, X_test_b, y_train_b, y_test_b = train_test_split(X, y_clean, test_size=0.2, random_state=42)

# %%
smote = SMOTE(random_state=42)
X_train_res_b, y_train_res_b = smote.fit_resample(X_train_b, y_train_b)

# %%
clf.fit(X_train_res_b,y_train_res_b)
# Out:
# C:\Users\Mcc\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(class_weight='balanced')

# %%
y_ped=clf.predict(X_test_b)

# %%
accuracy_score(y_pred,y_test_b)
# Out:
# 0.6874098990869774
