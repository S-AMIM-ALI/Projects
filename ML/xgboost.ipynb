# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification

# %%
x,y=make_classification(n_samples=1000,n_features=10,n_redundant=2,n_informative=8,n_classes=3)

# %%
df=pd.DataFrame(x)

# %%
df['target']=y

# %%
df.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -3.452339  0.287989  2.001365 -4.166544  0.407966  2.477057  1.588849
# 1 -1.762798  3.404323 -2.462788 -3.737065  1.024489  5.001531 -1.906540
# 2 -0.412375  0.667465  1.694318 -7.017542  0.360799  1.218241  1.569454
# 3  4.337387  2.979388  2.353821 -1.735429  1.280076  2.098818 -1.559321
# 4 -1.571540 -0.609870  0.112319  4.338183 -2.653646 -1.865903 -2.095153
#
#           7         8         9  target
# 0  3.467483 -0.951699 -0.621503       0
# 1 -0.029761 -1.576273  7.573313       1
# 2 -2.929905  1.680349  0.076305       1
# 3  0.791305 -3.298591 -2.334648       2
# 4 -2.059477 -3.619224  5.358493       1

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(df.iloc[:,:-1],df.iloc[:,-1],test_size=0.3,random_state=42)

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()

# %%
param_grid = {
    "n_estimators": [100, 200, 300],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 5, 7],
    "min_child_weight": [1, 3, 5],
    "gamma": [0, 0.2, 0.5]
    # "subsample": [0.8, 1.0],
    # "colsample_bytree": [0.8, 1.0],
    # "reg_alpha": [0, 0.1, 1],
    # "reg_lambda": [1, 2, 5]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid = GridSearchCV(
    estimator=xgb,
    param_grid=param_grid,
    cv=2,
    scoring="accuracy",
    n_jobs=-1,verbose=1
)
import time

# %%
start = time.time()

grid.fit(x_train, y_train)

end = time.time()

print("Training time:", end-start, "seconds")
# Out:
# Fitting 2 folds for each of 243 candidates, totalling 486 fits
# Training time: 176.14896750450134 seconds

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'gamma': 0, 'learning_rate': 0.05, 'max_depth': 7, 'min_child_weight': 1, 'n_estimators': 300}
# 0.8085714285714286

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_regression

# %%
x,y=make_regression(n_samples=1000,n_features=10,noise=0.3,random_state=42)

# %%
data=pd.DataFrame(x)
data['target']=y

# %%
from xgboost import XGBRegressor

# %%
model1 = XGBRegressor(
    objective="reg:squarederror",
    eval_metric="rmse",
    random_state=42,
    n_jobs=-1
)

# %%
model2 = XGBRegressor(
    objective="reg:squarederror",
    eval_metric="mae",
    random_state=42,
    n_jobs=-1
)

# %%
from sklearn.model_selection import RandomizedSearchCV

search = RandomizedSearchCV(
    estimator=model1,
    param_distributions=param_grid,
    n_iter=50,
    cv=3,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1,
    random_state=42
)

# %%
param_grid = {
    "n_estimators": [100, 200, 300],
    "learning_rate": [0.01, 0.05, 0.1],
    "max_depth": [3, 5, 7],
    "min_child_weight": [1, 3, 5],
    "gamma": [0, 0.2, 0.5]
    # "subsample": [0.8, 1.0],
    # "colsample_bytree": [0.8, 1.0],
    # "reg_alpha": [0, 0.1, 1],
    # "reg_lambda": [1, 2, 5]
}

# %%
s1 = RandomizedSearchCV(
    estimator=model1,
    param_distributions=param_grid,
    n_iter=50,
    cv=3,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1,
    random_state=42
)

# %%
s2 = RandomizedSearchCV(
    estimator=model2,
    param_distributions=param_grid,
    n_iter=50,
    cv=3,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1,
    random_state=42
)

# %%
s1.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric='mae', feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constrain...
#                                           min_child_weight=None, missing=nan,
# ...

# %%
s2.fit(x_train,y_train)
# Out:
# RandomizedSearchCV(cv=3,
#                    estimator=XGBRegressor(base_score=None, booster=None,
#                                           callbacks=None,
#                                           colsample_bylevel=None,
#                                           colsample_bynode=None,
#                                           colsample_bytree=None, device=None,
#                                           early_stopping_rounds=None,
#                                           enable_categorical=False,
#                                           eval_metric='mae', feature_types=None,
#                                           feature_weights=None, gamma=None,
#                                           grow_policy=None,
#                                           importance_type=None,
#                                           interaction_constrain...
#                                           min_child_weight=None, missing=nan,
# ...

# %%
print(s1.best_params_)
# Out:
# {'n_estimators': 300, 'min_child_weight': 5, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0.2}

# %%
print(s1.best_score_)
# Out:
# -0.5017293790976206

# %%
print(s2.best_params_)
print(s2.best_score_)
# Out:
# {'n_estimators': 300, 'min_child_weight': 5, 'max_depth': 5, 'learning_rate': 0.1, 'gamma': 0.2}
# -0.5017293790976206
