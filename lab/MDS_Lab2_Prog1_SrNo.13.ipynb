# %% [markdown]
# # MDS Lab 2 Program 1

# %% [markdown]
# # Name : Mohammad Farhan
# # Sr. No. : 13
# # Roll No. : 24MDS013
# # Student ID : 202404674
# # Enrollment No. : 24-05692

# %% [raw]
# Problem: Simple Linear Regression using Gradient Descent
#
# Daataset: Create single feature single target dataset using sklearn.datasets.make_regresion
#
# Task: Apply Gradient Descent on the dataset with single feature and target, and find the coefficients theta0 and theta1
#
# 1) Use matplotlib to perform data analysis on the dataset and plot scatter of data, plot distribution of feature and target
# 2) Normalize the dataset
# 3) Apply gradient descent
# 4) Calculate the coefficients
# 6) Plot the linear regression line
# 7) Analyze the model on various values of eta
# 8) Analyze the model on different size of data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
from sklearn.datasets import make_regression

# %%
X, y = make_regression(n_samples=200, n_features=1, n_targets=1, noise=20, random_state=40)

# %% [markdown]
# # 1) Use matplotlib to perform data analysis on the dataset and plot scatter of data, plot distribution of feature and target

# %%
plt.scatter(X, y, color = "#FA5417", marker = "x")
plt.xlabel("Independent Feature")
plt.ylabel("Dependent Feature")
plt.title("Scatter Plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 2) Normalize the dataset

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)

# %%
y = scaler.fit_transform(y.reshape(-1, 1))

# %%
plt.scatter(X, y, color = "#FA5417", marker = "x")
plt.xlabel("Independent Feature")
plt.ylabel("Dependent Feature")
plt.title("Scatter Plot, After preprocessing Data.")
plt.show()

# %%
sns.distplot(X, color = "#FA5417")
sns.distplot(y, color = "#AF3147")
plt.title("Distribution Plot")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # 3) Take Randomly coefficients, theta0, theta1

# %%
# let assume Initial random value of theta0, theta1
theta0 = 0
theta1 = 0

# %%
plt.scatter(X, y, color = "#FA5417", marker = "x")
plt.plot(X, theta0 + theta1*X, c = 'r')
plt.xlabel("Independent Feature")
plt.ylabel("Dependent Feature")
plt.title("Scatter Plot for Randomly theta0, theta1")
plt.show()

# %% [markdown]
# # 4) Apply gradient descent

# %%
# Gradien Descent iterating 1000 times to fit the curve.
eta = 0.01                                # learning rate
n = len(X)                                # total no. of data points
for i in range(1000):                     # iterating 1000 times
    y_pred = theta0 + theta1*X            # Calculate predicted value
    dL0 = (-2/n)*np.sum(y - y_pred)       # calculate the loss w.r.t theta0
    dL1 = (-2/n)*np.sum((y - y_pred)*X)   # Calculate the loss w.r.t theta1
    theta0 = theta0 - eta*dL0             # update the theta0 value to minimize the loss
    theta1 = theta1 - eta*dL1             # update the theta1 value to minimize the loss

# %% [markdown]
# # 5) Calculate the coefficients

# %%
print(f"updated value of theta 0 : {theta0}")
print(f"updated value of theta 1 : {theta1}")
# Out:
# updated value of theta 0 : 1.3744561044859437e-17
# updated value of theta 1 : 0.8817385071044764

# %% [markdown]
# # 6) Plot the linear regression line

# %%
plt.scatter(X, y, color = "#FA5417", marker = "x")
plt.plot(X, theta0 + theta1*X, c = 'r')
plt.xlabel("Independent Feature")
plt.ylabel("Dependent Feature")
plt.title("Scatter Plot, After applying Gradient Descent")
plt.show()

# %% [markdown]
# # 7) Analyze the model on various values of eta

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))


eta = [0.1, 0.01, 0.001, 0.0001]
n = len(X)                                # total no. of data points
a = 1
for j, ax in enumerate(axes.flat):
    
    theta0 = 0
    theta1 = 0
    for i in range(1000):                     # iterating 1000 times
        y_pred = theta0 + theta1*X            # Calculate predicted value
        dL0 = (-2/n)*np.sum(y - y_pred)       # calculate the loss w.r.t theta0
        dL1 = (-2/n)*np.sum((y - y_pred)*X)   # Calculate the loss w.r.t theta1
        theta0 = theta0 - eta[j]*dL0             # update the theta0 value to minimize the loss
        theta1 = theta1 - eta[j]*dL1             # update the theta1 value to minimize the loss
    ax.scatter(X, y, color = "#FA5417", marker = "x")
    ax.plot(X, theta0 + theta1*X, c = 'r')
    ax.set_title(f"Scatter Plot : eta = {eta[j]}")

# %% [markdown]
# # 8) Analyze the model on different size of data

# %%
from sklearn.datasets import make_regression
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.reshape(-1, 1))

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 8))
size = [100, 200, 400, 800]
n = len(X)                               # total no. of data points
eta = 0.01

for j, ax in enumerate(axes.flat):
    X, y = make_regression(n_samples=size[j], n_features=1, n_targets=1, noise=20, random_state=40)
    X = scaler.fit_transform(X)
    y = scaler.fit_transform(y.reshape(-1, 1))
    
    theta0 = 0
    theta1 = 0
    for i in range(1000):                     # iterating 1000 times
        y_pred = theta0 + theta1*X            # Calculate predicted value
        dL0 = (-2/n)*np.sum(y - y_pred)       # calculate the loss w.r.t theta0
        dL1 = (-2/n)*np.sum((y - y_pred)*X)   # Calculate the loss w.r.t theta1
        theta0 = theta0 - eta*dL0             # update the theta0 value to minimize the loss
        theta1 = theta1 - eta*dL1             # update the theta1 value to minimize the loss
    ax.scatter(X, y, color = "#FA5417", marker = "x")
    ax.plot(X, theta0 + theta1*X, c = 'r')
    ax.set_title(f"Scatter Plot : size = {size[j]}")
