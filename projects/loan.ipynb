# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("loanapproval.csv")

# %%
data.head()
# Out:
#    applicant_id  age  gender marital_status  annual_income  loan_amount  \
# 0             1   59    Male       Divorced         100073         7169
# 1             2   49    Male        Married         112197        23556
# 2             3   35    Male       Divorced          84429        27052
# 3             4   63  Female         Single         124195        11313
# 4             5   28  Female        Married          81627        13315
#
#    credit_score  num_dependents  existing_loans_count employment_status  \
# 0           793               1                     1        Unemployed
# 1           789               0                     2          Employed
# 2           372               1                     4        Unemployed
# 3           808               3                     4     Self-employed
# 4           689               0                     1        Unemployed
#
#    loan_approved
# 0              1
# 1              1
# 2              0
# 3              1
# 4              1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   applicant_id          1000 non-null   int64
#  1   age                   1000 non-null   int64
#  2   gender                1000 non-null   object
#  3   marital_status        1000 non-null   object
#  4   annual_income         1000 non-null   int64
#  5   loan_amount           1000 non-null   int64
#  6   credit_score          1000 non-null   int64
#  7   num_dependents        1000 non-null   int64
#  8   existing_loans_count  1000 non-null   int64
#  9   employment_status     1000 non-null   object
#  10  loan_approved         1000 non-null   int64
# dtypes: int64(8), object(3)
# memory usage: 86.1+ KB

# %%
data.drop(columns=['applicant_id'],inplace=True)

# %%
data.tail()
# Out:
#      age  gender marital_status  annual_income  loan_amount  credit_score  \
# 995   53  Female        Married         135598         6014           767
# 996   22    Male         Single         139028        15103           662
# 997   34  Female        Married         147517        21986           582
# 998   60  Female       Divorced          73161        49781           635
# 999   60  Female         Single         141316        35471           461
#
#      num_dependents  existing_loans_count employment_status  loan_approved
# 995               3                     2          Employed              1
# 996               0                     0     Self-employed              1
# 997               0                     2          Employed              1
# 998               4                     0        Unemployed              1
# 999               1                     1        Unemployed              1

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder,StandardScaler

# %%
data['marital_status'].unique()
# Out:
# array(['Divorced', 'Married', 'Single'], dtype=object)

# %%
print("num of dependenst=",data['num_dependents'].unique(),"=",data['num_dependents'].nunique(),'existing_loaan_acc=',
data['existing_loans_count'].unique()," employments_stattus=",
data['employment_status'].unique(),"gender=",
data['gender'].unique())
# Out:
# num of dependenst= [1 0 3 2 4] = 5 existing_loaan_acc= [1 2 4 0 3]  employments_stattus= ['Unemployed' 'Employed' 'Self-employed'] gender= ['Male' 'Female']

# %%
cols=['employment_status','gender','marital_status']
numeric=['annual_income','loan_amount','credit_score']

# %%
preprocessor=ColumnTransformer(
    transformers=[
        ('cat',OneHotEncoder(handle_unknown='ignore'),cols),
        ('scaled',StandardScaler(),numeric)
    ],
    remainder='passthrough'
)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
p1=Pipeline(steps=[
  ('preprocessor',preprocessor),
    ('classifier',LogisticRegression())
])

# %%
p2=Pipeline(steps=[
  ('preprocessor',preprocessor),
    ('classifier',RandomForestClassifier(n_estimators=100))
])

# %%
x,y=data.drop(columns=['loan_approved']),data['loan_approved']

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,accuracy_score

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
p1.fit(x_train,y_train)
# Out:
# C:\Users\Mcc\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\Mcc\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['employment_status',
#                                                    'gender',
#                                                    'marital_status']),
#                                                  ('scaled', StandardScaler(),
#                                                   ['annual_income',
#                                                    'loan_amount',
#                                                    'credit_score'])])),
#                 ('classifier', LogisticRegression())])

# %%
p2.fit(x_train,y_train)
# Out:
# C:\Users\Mcc\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['employment_status',
#                                                    'gender',
#                                                    'marital_status']),
#                                                  ('scaled', StandardScaler(),
#                                                   ['annual_income',
#                                                    'loan_amount',
#                                                    'credit_score'])])),
#                 ('classifier', RandomForestClassifier())])

# %%
y1_pred=p1.predict(x_test)

# %%
y2_pred=p2.predict(x_test)

# %%
accuracy_score(y1_pred,y_test)
# Out:
# 0.86

# %%
accuracy_score(y2_pred,y_test)
# Out:
# 0.97

# %%
import pickle

# %%
# Save the trained pipeline using pickle
pickle.dump(p1, open("m1.pkl", "wb"))

# %%
pickle.dump(p2,open('m2.pkl','wb'))

# %%
import keras
from keras import layers

def build_model(hp):
    model = keras.Sequential()

    # Number of convolutional layers
    for i in range(hp.Int("conv_layers", 1, 5)):
        model.add(
            layers.Conv2D(
                filters=hp.Int(f"filters_{i}", 32, 256, step=32),
                kernel_size=hp.Choice(f"kernel_size_{i}", [3, 5]),
                padding="same"
            )
        )

        model.add(layers.Activation(
            hp.Choice(f"activation_{i}", ["relu", "elu", "selu", "gelu", "swish"])
        ))

        model.add(layers.MaxPooling2D((2, 2)))

        model.add(
            layers.Dropout(
                hp.Float(f"dropout_{i}", 0.1, 0.5, step=0.1)
            )
        )

    # Dense head
    model.add(layers.Flatten())

    model.add(
        layers.Dense(
            units=hp.Int("dense_units", 64, 512, step=64),
            activation=hp.Choice(
                "dense_activation",
                ["relu", "elu", "selu", "gelu", "swish"]
            )
        )
    )

    model.add(
        layers.Dropout(
            hp.Float("dense_dropout", 0.2, 0.5, step=0.1)
        )
    )

    model.add(layers.Dense(2, activation="softmax"))

    # Optimizer
    optimizer_name = hp.Choice(
        "optimizer",
        ["sgd", "adam", "adamw", "rmsprop", "nadam"]
    )

    lr = hp.Float("learning_rate", 1e-4, 1e-2, sampling="log")

    optimizers = {
        "sgd": keras.optimizers.SGD(lr),
        "adam": keras.optimizers.Adam(lr),
        "adamw": keras.optimizers.AdamW(lr),
        "rmsprop": keras.optimizers.RMSprop(lr),
        "nadam": keras.optimizers.Nadam(lr),
    }

    model.compile(
        optimizer=optimizers[optimizer_name],
        loss="categorical_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
import keras_tuner as kt

# Define the tuner
tuner = kt.Hyperband(
    build_model,               # your build_model function
    objective="val_accuracy",  # what we want to maximize
    max_epochs=20,             # maximum epochs for the top models
    factor=3,                  # how aggressively to reduce configurations
    directory="my_tuner_dir",
    project_name="cnn_hyperband"
)

# Add an early stopping callback
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3)

# Start the hyperparameter search
tuner.search(
    x_train, y_train,
    epochs=20,                 # maximum epochs per trial
    validation_split=0.2,
    callbacks=[stop_early]
)

# %%
best_model = tuner.get_best_models(1)[0]
best_hp = tuner.get_best_hyperparameters(1)[0]

# Print number of convolutional layers
print("Conv layers:", best_hp.get("conv_layers"))

# Print number of filters for first conv layer
print("Filters in conv_0:", best_hp.get("filters_0"))

# Print chosen activation for first conv layer
print("Activation for conv_0:", best_hp.get("activation_0"))

# Print optimizer and learning rate
print("Optimizer:", best_hp.get("optimizer"))
print("Learning rate:", best_hp.get("learning_rate"))
print(

# %%
Number of conv layers: 5
Conv layer 0 filters: 96
Conv layer 0 activation: selu
Conv layer 0 kernel: 3
Conv layer 0 dropout: 0.30000000000000004
Conv layer 1 filters: 128
Conv layer 1 activation: elu
Conv layer 1 kernel: 3
Conv layer 1 dropout: 0.4
Conv layer 2 filters: 64
Conv layer 2 activation: swish
Conv layer 2 kernel: 5
Conv layer 2 dropout: 0.2
Conv layer 3 filters: 128
Conv layer 3 activation: relu
Conv layer 3 kernel: 5
Conv layer 3 dropout: 0.30000000000000004
Conv layer 4 filters: 64
Conv layer 4 activation: relu
Conv layer 4 kernel: 5
Conv layer 4 dropout: 0.30000000000000004
Dense units: 192
Dense activation: selu
Optimizer: adamw
Learning rate: 0.00012575252496942966
